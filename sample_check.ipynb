# %%
import requests
import json

url = "https://realty-in-us.p.rapidapi.com/properties/v3/list"
payload = {
    "limit": 5, "offset": 0, "postal_code": "90004",
    "status": ["for_sale", "ready_to_build"],
    "sort": {"direction": "desc", "field": "list_date"}
}
headers = {
    "x-rapidapi-key":"cba0c42875mshbb0655fd682190fp195895jsnbb5561e15581",
    "x-rapidapi-host": "realty-in-us.p.rapidapi.com",
    "Content-Type": "application/json"
}

resp = requests.post(url, json=payload, headers=headers).json()

if "data" not in resp:
    print("No data:", resp)
else:
    first = resp["data"]["home_search"]["results"][0]
    print(json.dumps(first, indent=2))
# Out:
# {
#   "__typename": "SearchHome",
#   "property_id": "2014320295",
#   "listing_id": "2999956163",
#   "plan_id": null,
#   "status": "for_sale",
#   "photo_count": 37,
#   "branding": [
#     {
#       "__typename": "Branding",
#       "photo": null,
#       "name": "The Bienstock Group",
#       "phone": null,
#       "link": null
#     }
#   ],
#   "location": {
#     "__typename": "SearchHomeLocation",
#     "address": {
#       "__typename": "SearchHomeAddress",
#       "city": "Los Angeles",
#       "line": "166 N McCadden Pl",
#       "street_name": "McCadden",
#       "street_number": "166",
#       "street_suffix": "Pl",
#       "country": "USA",
#       "postal_code": "90004",
#       "state_code": "CA",
#       "state": "California",
#       "coordinate": {
#         "__typename": "Coordinate",
#         "lat": 34.075631,
#         "lon": -118.336894,
#         "accuracy": null
#       }
#     },
#     "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&key=AIzaSyAP_xs30yS0J4xp8O1ZKUrUttIXKklrwaM&location=166%20N%20McCadden%20Pl%2C%20Los%20Angeles%2C%20CA%2090004&size=640x480&source=outdoor&signature=0AOitepXKE6IwlOmrlvR34ogjPw=",
#     "county": {
#       "__typename": "HomeCounty",
#       "fips_code": "06037"
#     }
#   },
#   "open_houses": [
#     {
#       "__typename": "HomeOpenHouse",
#       "start_date": "2026-08-23T12:00:00",
#       "end_date": "2026-08-23T14:00:00",
#       "description": null,
#       "time_zone": "PST"
#     }
#   ],
#   "description": {
#     "__typename": "SearchHomeDescription",
#     "sub_type": null,
#     "type": "single_family",
#     "beds": 5,
#     "baths": 6,
#     "lot_sqft": 10520,
#     "sqft": 5320,
#     "beds_max": null,
#     "beds_min": null,
#     "sqft_max": null,
#     "sqft_min": null,
#     "baths_full": 5,
#     "baths_half": 1,
#     "baths_min": null,
#     "baths_max": null,
#     "baths_full_calc": 5,
#     "baths_partial_calc": 1
#   },
#   "virtual_tours": null,
#   "matterport": false,
#   "advertisers": [
#     {
#       "__typename": "HomeAdvertiser",
#       "fulfillment_id": "621165",
#       "name": "Sheri Bienstock",
#       "email": "sheri.bienstock@gmail.com",
#       "href": "http://www.thebienstockgroup.com",
#       "slogan": "We love what we do!",
#       "type": "seller"
#     }
#   ],
#   "flags": {
#     "__typename": "SearchHomeFlags",
#     "is_price_reduced": null,
#     "is_new_construction": null,
#     "is_foreclosure": null,
#     "is_plan": null,
#     "is_new_listing": true,
#     "is_coming_soon": null,
#     "is_contingent": null,
#     "is_pending": null
#   },
#   "source": {
#     "__typename": "MlsSource",
#     "agents": [
#       {
#         "__typename": "MlsAgent",
#         "id": "WECA",
#         "agent_id": "X76580",
#         "agent_name": "Sheri Bienstock",
#         "office_id": "X81957",
#         "office_name": "The Bienstock Group"
#       }
#     ],
#     "id": "WECA",
#     "type": "mls",
#     "spec_id": null,
#     "plan_id": null,
#     "listing_href": null,
#     "listing_id": "26869495"
#   },
#   "pet_policy": null,
#   "community": null,
#   "primary_photo": {
#     "__typename": "HomePhoto",
#     "href": "https://ap.rdcpix.com/3fe75ee783aeb6f54fbc83d5a6a8a70el-m249511530s.jpg"
#   },
#   "href": "https://www.realtor.com/realestateandhomes-detail/166-N-McCadden-Pl_Los-Angeles_CA_90004_M20143-20295",
#   "list_price": 5399000,
#   "list_price_min": null,
#   "list_price_max": null,
#   "price_reduced_amount": null,
#   "estimate": {
#     "__typename": "LatestEstimate",
#     "estimate": 5246800
#   },
#   "lead_attributes": {
#     "__typename": "LeadAttributes",
#     "lead_type": "co_broke",
#     "show_contact_an_agent": true,
#     "opcity_lead_attributes": {
#       "__typename": "OpCityLeadAttributes",
#       "flip_the_market_enabled": true
#     }
#   },
#   "last_sold_date": "1997-08-22",
#   "list_date": "2026-08-21T19:34:34.000000Z",
#   "products": {
#     "__typename": "ProductSummarySearchHome",
#     "brand_name": "basic_opt_in",
#     "products": [
#       "core.agent",
#       "co_broke"
#     ]
#   },
#   "last_sold_price": 525000
# }
